# %%
import re
import sys
import json
sys.path.append('./../')
sys.path.append('./../../')
import random
import string
import urllib, json
from math import *
from operator import * 
from itertools import *
from collections import *

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity as cosine
from scipy.spatial.distance import euclidean
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score

from sklearn.metrics import normalized_mutual_info_score, adjusted_mutual_info_score, adjusted_rand_score

from sklearn.decomposition import PCA
from sklearn.decomposition import TruncatedSVD

from playgroundYelp import *
from modelYelp import *
session = getSession()

import plotly
import plotly.plotly as py
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='josephcc', api_key='G56dPHPPVbSeiaU0KutN')

# %%
GS = {}
for term in ['cocktail', 'basil', 'lemon']:
    with open('../gs/%s.gs.json' % term) as jsonfile:
        GS[term] = json.load(jsonfile)

# %%
def getVectorsForToken(token, limit=10000, table='business_token_vector_pittsburgh'):
    vectors = session.execute('SELECT business_id, vector FROM %s WHERE city = :city AND token = :token LIMIT :limit' % table, {
        'token': token,
        'limit': limit,
        'city': 'Pittsburgh'
    })
    vectors = list(vectors)
    business_ids = map(itemgetter(0), vectors)
    vectors = map(itemgetter(1), vectors)
    return business_ids, vectors

# %%
def silhouetteAnalysis(vectors, bids, gs, algorithm=lambda n_clusters: KMeans(n_clusters=n_clusters), repeat=1, Ks=range(2,8)):
    print 'silhouetteAnalysis START'
    print '| - # of restaurant vectors: ', len(vectors)

    scores = []
    for n_clusters in Ks:
        bestScore = -2
        bestResults = None
        for _ in range(repeat):
            clusterer = algorithm(n_clusters)
            cluster_labels = clusterer.fit_predict(np.asarray(vectors))
            try:
                silhouette_avg = silhouette_score(vectors, cluster_labels, sample_size=100)
            except:
                continue
            if silhouette_avg >= bestScore:
                bestScore = silhouette_avg
                bestResults = cluster_labels
        scores.append((n_clusters, bestScore, bestScore * (n_clusters ** 0.5), bestResults))
    scores.sort(key=itemgetter(1), reverse=True)

    print '| Ranking of different Ks:'
    for n, score, weightedScore, results in scores:
        print '| - K =', n, '\tscore:  %.4f' % score #, '\tKweighted: %.4f' % weightedScore
        evaluate(zip(results, bids), gs)

    print 'END silhouetteAnalysis'
    
    return scores

# %%
def getSnippetForBusinessAndToken(business_id, token, charwinsize=40):
    index = session.execute('''
        SELECT review_id, start, "end" FROM index
        WHERE "isName" = false AND business_id = :business_id AND token = :token
        ORDER BY business_id LIMIT 1
    ''', {'business_id': business_id, 'token': token})
    
    review_id, start, end = list(index)[0]
    substring = 'substring(text, %d, %d)' % (max(0, start - charwinsize), 2*charwinsize)
    mention = session.execute('''
        SELECT %s
        FROM review WHERE review_id = :review_id
        LIMIT 1
    ''' % substring, {'review_id': review_id})
    return list(mention)[0][0].replace('\n', ' ').strip()

# %%
def evaluate(results, gs):
    a = []
    b = []
    
    tr = {}
    for cid, name in enumerate(list(set(gs.values()))):
        if name in set(['others', 'other']):
            continue
        tr[name] = cid
    
    for cid, bid in results:
        if gs[bid] in set(['others', 'other']):
            continue
        a.append(cid)
        b.append(tr[gs[bid]])
        
        

    #print '\t|NMI:\t\t%.4f' % normalized_mutual_info_score(a,b)
    #print '\t|AMI:\t\t%.4f' % adjusted_mutual_info_score(a, b)
    print '|\t|randIDX:\t%.4f' % adjusted_rand_score(a, b)
    
    print '|\t|clusterP:\t',
    purity = 0.0
    for cid, group in groupby(sorted(zip(a,b), key=itemgetter(0)), key=itemgetter(0)):
        labels = map(itemgetter(1), group)
        N = float(len(labels))
        n = Counter(labels).most_common()[0][1]
        print '(%d:%.0f%%),' % (N, 100*n/N),
        purity += (float(n)/N) * (float(N)/len(a))
    print '\n\t|purity:\t%.2f%%' % (100*purity)

# %%
def run(algorithm=lambda n_clusters: KMeans(n_clusters=n_clusters), tokens=('basil', 'cocktail', 'lemon'), repeat=1, Ks=range(2,6)):
    for token in tokens:
        print '=' * 33        
        print token
        print '=' * 33        
        business_id, vectors = getVectorsForToken(token, 10000, 'vector_backup')
        #business_id, vectors = getVectorsForToken(token, 10000)
        
        '''
        svd = TruncatedSVD(n_components=50)
        vectors = svd.fit_transform(vectors)
        
        pca = PCA(n_components=150)
        vectors = pca.fit_transform(vectors)
        '''
        
        gs = GS[token]
        scores = silhouetteAnalysis(vectors, business_id, gs, algorithm=algorithm, repeat=repeat)
        n, score, weightedResults, results = scores[0]
        results = sorted(zip(results, business_id))
        '''
        for cluster_id, payload in groupby(results, key=itemgetter(0)):
            bids = map(itemgetter(1), payload)
            print ' __________'
            print '|CLUSTER', cluster_id, '|', 'size:', len(bids) 
            print ' ----------'
            bids = random.sample(bids, min(5, len(bids)))
            for bid in bids:
                print '- ...%s...' % getSnippetForBusinessAndToken(bid, token)
        '''

        print
        print

# %%
run(KMeans, Ks=range(1, 3), repeat=5)
# Out:
# =================================
# basil
# =================================
# silhouetteAnalysis START
# | - # of restaurant vectors:  324
# | Ranking of different Ks:
# | - K = 3 	score:  0.0665
# |	|randIDX:	0.2643
# |	|clusterP:	(150:66%), (46:70%), (122:64%),
# 	|purity:	65.72%
# | - K = 5 	score:  0.0662
# |	|randIDX:	0.1848
# |	|clusterP:	(24:92%), (71:55%), (30:87%), (29:62%), (164:63%),
# 	|purity:	65.41%
# | - K = 2 	score:  0.0648
# |	|randIDX:	0.1187
# |	|clusterP:	(190:53%), (128:62%),
# 	|purity:	56.60%
# | - K = 4 	score:  0.0560
# |	|randIDX:	0.1571
# |	|clusterP:	(109:45%), (137:63%), (29:90%), (43:77%),
# 	|purity:	61.01%
# | - K = 6 	score:  0.0423
# |	|randIDX:	0.2419
# |	|clusterP:	(72:50%), (90:86%), (68:54%), (49:67%), (1:100%), (38:82%),
# 	|purity:	67.61%
# | - K = 7 	score:  0.0418
# |	|randIDX:	0.2034
# |	|clusterP:	(14:43%), (36:58%), (70:43%), (36:86%), (30:90%), (92:80%), (40:50%),
# 	|purity:	65.72%
# END silhouetteAnalysis
#
#
# =================================
# cocktail
# =================================
# silhouetteAnalysis START
# | - # of restaurant vectors:  422
# | Ranking of different Ks:
# | - K = 2 	score:  0.1704
# |	|randIDX:	0.3588
# |	|clusterP:	(107:61%), (307:99%),
# 	|purity:	89.13%
# | - K = 7 	score:  0.1218
# |	|randIDX:	0.3769
# |	|clusterP:	(303:99%), (1:100%), (2:100%), (86:73%), (1:100%), (20:95%), (1:100%),
# 	|purity:	93.48%
# | - K = 5 	score:  0.0931
# |	|randIDX:	0.2286
# |	|clusterP:	(267:99%), (37:100%), (89:53%), (20:100%), (1:100%),
# 	|purity:	89.13%
# | - K = 3 	score:  0.0795
# |	|randIDX:	0.2814
# |	|clusterP:	(99:100%), (276:97%), (39:92%),
# 	|purity:	97.10%
# | - K = 4 	score:  0.0702
# |	|randIDX:	0.3311
# |	|clusterP:	(48:100%), (294:99%), (1:100%), (71:58%),
# 	|purity:	91.79%
# | - K = 6 	score:  0.0473
# |	|randIDX:	0.1597
# |	|clusterP:	(57:93%), (42:100%), (50:100%), (20:85%), (225:97%), (20:90%),
# 	|purity:	96.38%
# END silhouetteAnalysis
#
#
# =================================
# lemon
# =================================
# silhouetteAnalysis START
# | - # of restaurant vectors:  457
# | Ranking of different Ks:
# | - K = 2 	score:  0.0503
# |	|randIDX:	0.3725
# |	|clusterP:	(159:50%), (288:75%),
# 	|purity:	66.22%
# | - K = 4 	score:  0.0472
# |	|randIDX:	0.3392
# |	|clusterP:	(70:80%), (136:46%), (204:83%), (37:89%),
# 	|purity:	71.59%
# | - K = 3 	score:  0.0452
# |	|randIDX:	0.3571
# |	|clusterP:	(283:72%), (66:83%), (98:69%),
# 	|purity:	73.38%
# | - K = 5 	score:  0.0401
# |	|randIDX:	0.2578
# |	|clusterP:	(31:61%), (132:47%), (33:85%), (87:74%), (164:84%),
# 	|purity:	69.57%
# | - K = 6 	score:  0.0331
# |	|randIDX:	0.3000
# |	|clusterP:	(128:86%), (112:79%), (16:81%), (73:79%), (65:83%), (53:60%),
# 	|purity:	79.42%
# | - K = 7 	score:  0.0295
# |	|randIDX:	0.2443
# |	|clusterP:	(16:81%), (59:66%), (77:77%), (160:68%), (101:90%), (31:87%), (3:33%),
# 	|purity:	75.84%
# END silhouetteAnalysis

# %%
#run(AgglomerativeClustering, repeat=20)

# %%
from sklearn.metrics.pairwise import cosine_similarity as cosine
from scipy.spatial.distance import euclidean

def bow2vec(tokens, weights):
    tokens = filter(lambda tok: tok in model, tokens)
    vector = map(lambda token: model[token], tokens)
    vector = [w*v for w, v in zip(weights, vector)]
    vector = np.asarray(vector).sum(0)
    return vector/vector.sum()

def query(token, query, weights):
    print 'Context vector query:', token, '+ Vector(' + str(zip(query, weights)), ')'
    bids, vectors = getVectorsForToken(token, 10000, 'vector_backup')
    gs = GS[token]

    vector = bow2vec(query, weights)
#    cosines = [(idx, weight*cosine([vector], [Vr])[0][0]) for idx, Vr in enumerate(vectors)]
    #cosines = [(idx, -1 * weight*euclidean(vector, Vr)) for idx, Vr in enumerate(vectors)]
    #if weight < 0:
    #    cosines = [(idx, ((euclidean(vector, Vr) + euclidean(vector, basil) / euclidean(vector, Vr)))) for idx, Vr in enumerate(vectors)]
    #else:
    #    cosines = [(idx, (1.0 - (euclidean(vector, Vr) + euclidean(vector, basil) / euclidean(vector, Vr)))) for idx, Vr in enumerate(vectors)]
    
    vectors = [Vr/float(sum(Vr)) for Vr in np.asarray(vectors)]
    cosines = [(idx, cosine([vector], [Vr])[0][0]) for idx, Vr in enumerate(vectors)]
    
    #cosines = [(idx, cosine([vector], [np.asarray(Vr)/float(sum(Vr))])[0][0]) for idx, Vr in enumerate(vectors)]
    
    cosines.sort(key=itemgetter(1), reverse=True)
    rank = 0
    for idx, cos in cosines[:20]:
        rank += 1
        bid = bids[idx]
        print '%s %.2f %s\t ...%s...' % ("{0: >2}".format(rank), cos, gs[bid], getSnippetForBusinessAndToken(bid, token))
    print '-' * 88
    return [gs[bids[idx]] for idx, cos in cosines], {bids[idx]: cos for idx, cos in cosines}

URL = 'http://j.pc.cs.cmu.edu:5000/baseline_search/Pittsburgh/0.0/%s/%s'
def bm25(query, token, bid2cosine):
    print 'BM25 query:', query
    gs = GS[token]
    query = query.split()
    query = '%7C'.join(query)
    weight = '%7C'.join(['1',] * len(query))
    url = URL % (query, weight)

    response = urllib.urlopen(url)
    data = json.loads(response.read())
    bids = map(itemgetter('business_id'), data['business'])
    for rank, business in enumerate(data['business'][:20]):
        print str(rank+1).rjust(2, ' '),
        print ('%.2f' % bid2cosine.get(business['business_id'], 0.0)).rjust(5, '+'),
        print gs.get(business['business_id'], '???').rjust(10, ' '), '  ',
        #print business['name']
        
        mentions = data['review'][business['business_id']]
        mentions = filter(lambda mention: token in mention['text'], mentions)
        if len(mentions) == 0:
            print '(no mentions of %s)' % token
            continue
        mention = random.sample(mentions, 1)[0]['text']
        idx = mention.index(token)
        win = 35
        mention = mention[max(0, idx-win):idx+win+len(token)]
        print mention.replace('\n', ' ')
        
    print '-' * 88
        
    return [gs.get(bid, 'NotFound') for bid in bids]

# %%
def dcg(rank, k):
    out = 0.0
    for _k in range(k):
        out += ((2**rank[_k]) - 1) / log(_k+1+1, 2)
    return out
        
def ndcg(ranks, target, k=30):
    k = min(k, len(ranks))
    ranks = [rank == target and 1.0 or 0.0 for rank in ranks]
    idea_ranks = sorted(ranks[:], reverse=True)
    outs = []
    for _k in range(k):
        outs.append(dcg(ranks, _k+1)/dcg(idea_ranks, _k+1))
    return outs

def precision(ranks, target, k=30):
    k = min(k, len(ranks))
    ranks = [rank == target and 1.0 or 0.0 for rank in ranks]
    outs = []
    for _k in range(k):
        outs.append(Counter(ranks[:_k+1])[1]/float(_k+1))
    return outs

def recall(ranks, target, N, k=30):
    k = min(k, len(ranks))
    ranks = [rank == target and 1.0 or 0.0 for rank in ranks]
    outs = []
    for _k in range(k):
        outs.append(Counter(ranks[:_k+1])[1]/N)
    return outs

def plot(system, baseline, target, N):
    data = []
    systemColor = ('rgb(22, 96, 167)')
    baselineColor = ('rgb(215, 96, 92)')
    data.append(go.Scatter(
        x = range(1, len(system) + 1),
        y = ndcg(system, target),
        mode = 'lines',
        name = 'System nDCG',
        line = dict(
            color = systemColor,
            width = 3,
            dash = 'line'
        )
    ))
    data.append(go.Scatter(
        x = range(1, len(baseline) + 1),
        y = ndcg(baseline, target),
        mode = 'lines',
        name = 'Baseline nDCG',
        line = dict(
            color = baselineColor,
            width = 3,
            dash = 'line'
        )
    ))
    data.append(go.Scatter(
        x = range(1, len(system) + 1),
        y = precision(system, target),
        mode = 'lines',
        name = 'System Precision',
        line = dict(
            color = systemColor,
            width = 1,
            dash = 'dot'
        )
    ))
    data.append(go.Scatter(
        x = range(1, len(baseline) + 1),
        y = precision(baseline, target),
        mode = 'lines',
        name = 'Baseline Precision',
        line = dict(
            color = baselineColor,
            width = 1,
            dash = 'dot'
        )
    ))
    data.append(go.Scatter(
        x = range(1, len(system) + 1),
        y = recall(system, target, N),
        mode = 'lines',
        name = 'System Recall',
        line = dict(
            color = systemColor,
            width = 1,
            dash = 'dash'
        )
    ))
    data.append(go.Scatter(
        x = range(1, len(baseline) + 1),
        y = recall(baseline, target, N),
        mode = 'lines',
        name = 'Baseline Recall',
        line = dict(
            color = ('rgb(255, 146, 142)'),
            width = 1,
            dash = 'dash'
        )
    ))
    
    f1 = []
    for p, r in zip(precision(baseline, target), recall(baseline, target, N)):
        if p+r == 0:
            f1.append(0.0)
        else:
            f1.append(2*p*r/(p+r))
    data.append(go.Scatter(
        x = range(1, len(baseline) + 1),
        y = f1,
        mode = 'lines',
        name = 'Baseline F1',
        line = dict(
            color = ('rgb(252, 214, 214)'),
            width = 5,
            dash = 'line'
        )
    ))
    
    f1 = []
    for p, r in zip(precision(system, target), recall(system, target, N)):
        if p+r == 0:
            f1.append(0.0)
        else:
            f1.append(2*p*r/(p+r))
    data.append(go.Scatter(
        x = range(1, len(system) + 1),
        y = f1,
        mode = 'lines',
        name = 'System F1',
        line = dict(
            color = ('rgb(201, 222, 255)'),
            width = 5,
            dash = 'line'
        )
    ))

    return py.iplot(list(reversed(data)), filename='searchlens')

def search(token, naive, target, terms, weights):
    #baseline = query(token, [token], [1])
    system, bid2cosine = query(token, terms + [token,], weights + [1,])
    baseline = bm25(naive, token, bid2cosine)
    N = float(sum([outcome == target and 1.0 or 0.0 for outcome in GS[token].values()]))
    return plot(system, baseline, target, N)

# %%
search('cocktail', 'shrimp cocktail suace', 'sauce', ['seafood','drinks'], [1,-1])
# Out:
# Context vector query: cocktail + Vector([('seafood', 1), ('drinks', -1), ('cocktail', 1)] )
#  1 0.32 sauce	 ...lse can you find unlimited sushi, shrimp cocktail, crawfish, clams, hot and sour...
#  2 0.28 sauce	 ...i, middle neck clams, and dumplings, and cocktail shrimp. EVERYTHING was amazing...
#  3 0.27 sauce	 ...ll, probably U-20 count which for Shrimp Cocktail is tiny. The wings were very d...
#  4 0.25 sauce	 ...- small salad bar, seafood salad, shrimp cocktail, etc. were good except a few o...
#  5 0.24 sauce	 ...I also had the shrimp appetizer (5 giant cocktail shrimp).    Took a long time t...
#  6 0.23 drinks	 ...plate of coconut shrimp. We also ordered cocktails: the Geisha's Delight and a Z...
#  7 0.22 drinks	 ...nting  and uninspired meal. We ordered a cocktail and hot tea. Received the cock...
#  8 0.21 sauce	 ...eese, lobster mashed potatoes and shrimp cocktail.  The sushi roll I had was top...
#  9 0.21 sauce	 ...ome dipping sauces and I was recommended cocktail for the seafood and cheese for...
# 10 0.21 sauce	 ...at sushi, crab legs, whole crabs, shrimp cocktail...  They also have standard Ch...
# 11 0.20 drinks	 ...for happy hour. The service was good. My cocktail was fine.  The mini lobster ro...
# 12 0.20 drinks	 ...rdered our drinks, which were okay-mixed cocktails but was pretty astounded when...
# 13 0.20 sauce	 ...but the right food is great. The seafood cocktail is awesome, and its the only r...
# 14 0.19 drinks	 ...ughter. I had the calamari with pasta, a cocktail ( yum, yum), and a garden sala...
# 15 0.18 drinks	 ...Grilled cheese. Cocktails. Great atmosphere, ambiance, and service. How can I n...
# 16 0.18 sauce	 ...e for after your dinner & enjoy the many cocktails available in the cigar bar....
# 17 0.17 drinks	 ....  We started with the "margarita shrimp cocktail".  Imagine tiny round pieces o...
# 18 0.17 sauce	 ...he coldness of the shrimp. I like shrimp cocktail but this shrimp was just not d...
# 19 0.17 sauce	 ...ppetizers we ordered crabmeat and shrimp cocktail, which were both good. Followi...
# 20 0.17 drinks	 ...out the food.  I also tried the fujiyama cocktail which is vodka, pina colada an...
# ----------------------------------------------------------------------------------------
# BM25 query: shrimp cocktail suace
#  1 -0.08     drinks     gin and tonic and a house special cocktail.  We ordered a pizza to share and
#  2 +0.00        ???    (no mentions of cocktail)
#  3 -0.15     drinks    s in action. I had a killer mezcal cocktail. I wasn't surprised that I loved i
#  4 -0.13     drinks       I also loved the variety on the cocktail menu - great cocktails, champagne,
#  5 -0.11     drinks    der, skewers, as well as beers and cocktails are half off from 5-7pm on the we
#  6 -0.17     drinks     shishitos at the same time as the cocktails - they came out insanely quickly.
#  7 -0.18     drinks    entation on the traditional shrimp cocktail, called the smoking shrimp cocktai
#  8 -0.10     drinks    ng intrusive very, very well.  The cocktail menu was a little small, and I lik
#  9 -0.10     drinks    ur coats at the door.  I tried two cocktails. The Hattori Hanzo was pretty goo
# 10 -0.13     drinks    are two bartenders-one is mixing a cocktail and cannot take his eyes away from
# 11 +0.10     drinks    is fish and chips were served with cocktail sauce, again, very strange.  The f
# 12 +0.07     drinks    l... I enjoyed every bite. And the cocktails are on point!!! The pictures I to
# 13 -0.13     drinks    eve here. They have a great mix of cocktails. The atmosphere and vibe are very
# 14 +0.04      sauce    s underdone and pretty bland.  The cocktail sauce helped a lot, but some tarta
# 15 -0.17     drinks    Raw oysters and Shrimp cocktail excellent Clam chowder flavorful b
# 16 +0.16      sauce    nitially impressed to see homemade cocktail sauce. I was disappointed in the f
# 17 -0.00     drinks     from a strong but delicious fancy cocktail. Prepare to stuff your face with p
# 18 -0.06     drinks    n a little empty!  We started with cocktails - I got the "Caribbean Mojito" wh
# 19 -0.14     drinks     restaurant has a fairly extensive cocktail, beer, and wine list and my cousin
# 20 +0.05     drinks     Now onto the food and drinks. The cocktails were appropriately titled from El
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('lemon', 'lemon cocktails', 'drinks', ['cocktail', 'drinks', 'desserts'], [1, 1,-1])
# Out:
# Context vector query: lemon + Vector([('cocktail', 1), ('drinks', 1), ('desserts', -1), ('lemon', 1)] )
#  1 0.59 drinks	 ...amble cocktail (gin, blackberry cordial, lemon) and the hallumi. The cocktail wa...
#  2 0.49 drinks	 ...was unbelievable - who knew rosemary and lemon flavors make a good cocktail!?! A...
#  3 0.46 drinks	 ...arm pita bread. It had a really distinct lemon flavor that I loved. I was surpri...
#  4 0.45 dishes	 ...peno essence. The rye whiskey drink with lemon was one of the best cocktails I'v...
#  5 0.45 drinks	 ...was just a sour glass of Ginger Ale and Lemon. The Deuce's Wild Mint Lemonade w...
#  6 0.45 drinks	 ...o Bloody Mary mix, vodka, old bay rim, a lemon and a lime. Literally poured the...
#  7 0.44 dishes	 ...ini: Fresh muddled basil, fresh squeezed lemon, gin, st. germaine.  Not as good...
#  8 0.41 dishes	 ...re a bit underdone and had been hit with lemon juice or some other acid before s...
#  9 0.41 drinks	 ...ain's elderflower liquor, gin, cucumber, lemon and champagne.  It was refreshing...
# 10 0.41 dessert	 ...ercussive ecuatorial essence of both the lemon and mango purees.   Kay and her c...
# 11 0.40 drinks	 ..." sorbet. It was a mix of mango, ginger, lemon, etc. and after eating it, the re...
# 12 0.40 drinks	 ...ad their food, they have that Pellegrino lemon and orange soda in their case if...
# 13 0.39 dishes	 ...cious sound cocktails and we opted for a lemon basil martini. It sounded so good...
# 14 0.39 dessert	 ...brûlée was decent, but a little too much lemon flavor. You can see the granules...
# 15 0.39 drinks	 ...ders were quick and friendly. We ordered lemon drop martinis and the Nacho appet...
# 16 0.38 drinks	 ...like an old fashioned. The Bertha, with lemon shrub, gin, and muddled cucumber...
# 17 0.38 drinks	 ...additives. Lime, grape, orange, cherry, lemon, and raspberry! I wanted to play...
# 18 0.38 drinks	 ..., I could get cherry vanilla, raspberry, lemon, lime and a couple other choices....
# 19 0.37 drinks	 ...in, a french liqueur, along titos vodka, lemon, and Green Chartreuse.  Its light...
# 20 0.37 drinks	 ...at cost $10 and had a giant thumb-shaped lemon zest garnish in it?  A total scam...
# ----------------------------------------------------------------------------------------
# BM25 query: lemon cocktails
#  1 -0.35     drinks    ka, black currant, vermouth, burnt lemon) which turned out to be very good.
#  2 +0.23    dessert    -this-world blueberry pancake with lemon creme fraiche (a single plate-size
#  3 +0.21    dessert    I didn't get any of the ginger and lemon ingredients. Every single item tha
#  4 +0.39    dessert    ch was Applejack, Campari, ginger, lemon, cinnamon, and Prosecco. DELIGHTFU
#  5 +0.32    dessert    (no mentions of lemon)
#  6 +0.24     drinks    y date and I shared the pig candy, lemon cake, and ordered two Waygu flank
#  7 +0.15    dessert    s good), some lavender powder, and lemon curd. The dessert was good - great
#  8 +0.25     dishes    oved the char-grilled oysters with lemon and garlic. We also sampled the sm
#  9 +0.29     drinks    real smooth.*  Next, I ordered the lemon gin.  I wasn't as much of a fan of
# 10 +0.15    dessert    OTTA blueberry consommé, hazelnut, lemon, hibiscus cucumber-elderflower spr
# 11 +0.22     dishes     beignets with raspberry and Meyer lemon sauces to smoked pork huevos ranch
# 12 +0.20     dishes    d as rye with fig jam, bitters and lemon, sounded like something that canno
# 13 -0.40     drinks    (no mentions of lemon)
# 14 +0.20    dessert    d he came up with a drink that had lemon juice, Bols Genever, St. Germaine,
# 15 +0.18     dishes    ey Snap...Art In The Age Snap with lemon syrup, a touch of scotch and an or
# 16 +0.28     dishes    side with the tips having the most lemon butter flavor.  I would normally r
# 17 -0.39     drinks    ouse cocktails, I had the lavender lemon vodka martini and it was amazing.
# 18 -0.42     drinks    e drink!  I ordered the strawberry lemonade because the waitress explained
# 19 +0.49     drinks    en. With Gozio amaretto, Zaya rum, lemon, orange, egg white and sparkling w
# 20 +0.16     dishes    ave ever had! I also recommend the lemon mustard dressing with the zucchini
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('lemon', 'lemon desserts', 'dessert', ['desserts'], [1])
# Out:
# Context vector query: lemon + Vector([('desserts', 1), ('lemon', 1)] )
#  1 0.57 dessert	 ...ing and so creative (bruleed grapefruit, lemon mousse with meringue and shortbre...
#  2 0.55 dishes	 ...re a bit underdone and had been hit with lemon juice or some other acid before s...
#  3 0.51 dessert	 ...e, and totally loved it! Why? 2 reasons: LEMON GINGER COOKIES and BACON MAC n CH...
#  4 0.50 dessert	 ...something I wanted to finish. My fish -- lemon sage ahi tuna -- was decent. My k...
#  5 0.48 dessert	 ...t's so intoxicatingly delicious. And the lemon lavender cupcakes...that's an ent...
#  6 0.46 dessert	 ...brûlée was decent, but a little too much lemon flavor. You can see the granules...
#  7 0.44 dishes	 ...sert, I ordered the yogurt, he the Meyer lemon. The Meyer lemon with sesame cake...
#  8 0.44 dishes	 ...ssive array of Italian sodas (lavender & lemon, mango & lime, white choc & mint,...
#  9 0.44 dishes	 ...e special--trout. Yum! My guests had the lemon chicken, the salmon and the pasta...
# 10 0.43 dessert	 ...amazing. My wife had the French 120, gin lemon grapefruit-tarragon and sparkling...
# 11 0.43 dessert	 ...ly be my carry on for the flight home!   Lemon Tarte- I love lemon and this one...
# 12 0.43 dessert	 ...hocolate with roses) for my second.  The lemon ginger was nice, but lacked the t...
# 13 0.42 drinks	 ...essert we had the chocolate tart and the lemon sponge cake. The lemon sponge cak...
# 14 0.42 dessert	 ...ith chai w/cinnamon frosting, pistachio, lemon raspberry, and chocolate hazelnut...
# 15 0.42 dessert	 ...he flavors were subtle and pure. I had a lemon and a a raspberry.   The only rea...
# 16 0.41 dessert	 ...ans & honey was very nice, a bit dry. My lemon sole over tabulleh style cous cou...
# 17 0.41 dessert	 ...nd raspberry flavors, but they had meyer lemon which I don't see that much so I...
# 18 0.41 drinks	 ...additives. Lime, grape, orange, cherry, lemon, and raspberry! I wanted to play...
# 19 0.41 drinks	 ...ad their food, they have that Pellegrino lemon and orange soda in their case if...
# 20 0.41 dishes	 ...oasted red peppers and fresh ricotta and lemon. The lemon was a bit overpowering...
# ----------------------------------------------------------------------------------------
# BM25 query: lemon desserts
#  1 +0.42    dessert    onal; my favorites are caramel and lemon.  They are not cheap, however. $2+
#  2 +0.40     dishes    icken souvlakia. Fun to share! The lemon potatoes were unique! We also had
#  3 -0.13      grass    uffed to the gills. My fave is the lemon grass "chicken", crunchy and fried
#  4 +0.43    dessert    d made in house.  This time it was lemon poppy seed bread and cranberry muf
#  5 +0.44     dishes    tto, loup de mer, ribeye and meyer lemon while my girlfriend went with the
#  6 +0.36    dessert    omato slices, onion, cucumber, and lemon.   People make it seem as if every
#  7 +0.13     dishes    ch was why I liked it better.  The lemon chicken orzo soup was delicious; c
#  8 +0.23     dishes    le days later - don't scoff at the lemon goat cheese truffles. Get them bec
#  9 +0.43    dessert    rt of the meal! I'm partial to the lemon mousse as it reminded me a lot of
# 10 +0.14     dishes    ounted them) garbanzo beans.    My lemon chicken with peppers consisted of
# 11 +0.39    dessert    Japanese cheesecake with lavender, lemon curd, and pistachio: The cheesecak
# 12 +0.25     dishes    which has a very unique taste with lemon juice. So is the kibbe; one of the
# 13 +0.55     dishes    r shrimp and angel hair pasta with lemon Creme. It also lacked flavor. I or
# 14 +0.43    dessert    flight home!   Lemon Tarte- I love lemon and this one is a great classic wi
# 15 +0.44     dishes    d had the pasta trio and I had the lemon chicken. One of the pastas was a l
# 16 +0.46    dessert    ch was Applejack, Campari, ginger, lemon, cinnamon, and Prosecco. DELIGHTFU
# 17 -0.28    dessert    cover the yolky taste with all the lemons in the world.     I ended up givi
# 18 +0.31     dishes    y strained Greek yogurt stuff with lemon that was so yummy I seriously cons
# 19 +0.29     dishes    arinated chicken breast, preserved lemons, cured olives, tumeric reduction,
# 20 -0.18     dishes    ked and you could really taste the lemon infused in everything, right down
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('lemon', 'lemon chicken', 'dishes', ['chicken'], [1])
# Out:
# Context vector query: lemon + Vector([('chicken', 1), ('lemon', 1)] )
#  1 0.72 dishes	 ...the special and told me I should try the lemon chicken. His name was Lou and he...
#  2 0.62 dishes	 ...re a bit underdone and had been hit with lemon juice or some other acid before s...
#  3 0.60 dessert	 ...something I wanted to finish. My fish -- lemon sage ahi tuna -- was decent. My k...
#  4 0.58 dishes	 ...red soups, salads, sushi, fried rice and lemon chicken! All were great! When you...
#  5 0.56 dishes	 ...the orange chicken, sesame chicken, and lemon chicken. All are delicious. I've...
#  6 0.54 dishes	 ...p. It's almost in edible. It tasted like lemon. Period. Not only that they clear...
#  7 0.54 dishes	 ...as, and cracked wheat) and Shish Tawook (lemon mint chicken) and both were out o...
#  8 0.53 dishes	 ...that they don't even give you a wedge of lemon to squeeze on your lemon chicken...
#  9 0.52 dishes	 ...w, it is really bad.  My husband had the lemon chicken and I think wall paperpas...
# 10 0.52 dessert	 ...brûlée was decent, but a little too much lemon flavor. You can see the granules...
# 11 0.52 dishes	 ...l service"--a warm damp towel and a half lemon to clean up with, which did help....
# 12 0.50 dessert	 ...ing and so creative (bruleed grapefruit, lemon mousse with meringue and shortbre...
# 13 0.50 dishes	 ...e special--trout. Yum! My guests had the lemon chicken, the salmon and the pasta...
# 14 0.50 dishes	 ...ok...everything kind of tastes the same. Lemon chicken is good but it's all pret...
# 15 0.49 dessert	 ...ans & honey was very nice, a bit dry. My lemon sole over tabulleh style cous cou...
# 16 0.49 dishes	 ...ampler with their General Tso's chicken, Lemon Chicken and white-sauce chicken (...
# 17 0.49 dishes	 ...ng dish.   Do yourself a favor order the Lemon Chicken with seshwan* sauce inste...
# 18 0.47 dishes	 ...quality is excellent. I'd recommend the lemon chicken in particular. They have...
# 19 0.46 dishes	 ...ssive array of Italian sodas (lavender & lemon, mango & lime, white choc & mint,...
# 20 0.46 dishes	 ...icken tasted like ammonia, I ordered the lemon chicken with brown rice. Seriousl...
# ----------------------------------------------------------------------------------------
# BM25 query: lemon chicken
#  1 +0.54     dishes    so asked for a taste of their avgholemono soup. It's almost in edible. It t
#  2 -0.29     dishes     chicken gyros, and definitely the lemon potatoes.  The salmon in pastry sh
#  3 +0.21     others    ately - soup was not very spicy or lemon grassy - which is ironic given the
#  4 -0.31      grass    Great vegan food, the lemon grass chicken has AMAZING flavor a
#  5 +0.39    dessert    one choices of blueberry/peach and lemon/lemon ginger.  Those were actually
#  6 +0.43     dishes    tto, loup de mer, ribeye and meyer lemon while my girlfriend went with the
#  7 -0.31     dishes    ir "rice bowl," which comes with a lemon rice (lentils optional), your choi
#  8 +0.32     dishes    tarted with the hummus of the day- lemon and cilantro. The presentation was
#  9 -0.24     dishes    ked and you could really taste the lemon infused in everything, right down
# 10 +0.33     dishes    ; the perfect amount of garlic and lemon.  If I ever end up on death row, m
# 11 +0.34     dishes     a fairly sized portion.  It had a lemon beurre blanc sauce, which was real
# 12 +0.41     dishes    entil soup always a winner.  Greek lemon and chicken soup was so light and
# 13 +0.31     dishes    h the crab cake and it came with a lemon mustard dressing which gave it the
# 14 -0.22     dishes    ly well done. My favorites are the lemon pepper and Louisiana, both dry rub
# 15 +0.28     dishes    s complied with my request for the lemon caper butter sauce on the side and
# 16 +0.36    dessert    -this-world blueberry pancake with lemon creme fraiche (a single plate-size
# 17 -0.33    dessert    ally good and came with a homemade lemon and oil dressing which i loved. Le
# 18 -0.27    dessert     all loved it too).  I ordered the lemon curd and berry French toast and it
# 19 -0.19    dessert    ich included a beautiful, homemade lemon vinaigrette on the side. The coffe
# 20 +0.34     dishes    c, cilantro and tomatoes cooked w/ lemon. Vegetable Momos - Again, amazing.
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('basil', 'basil cocktail', 'drinks', ['pizza', 'cocktail'], [-1,1])
# Out:
# Context vector query: basil + Vector([('pizza', -1), ('cocktail', 1), ('basil', 1)] )
#  1 0.54 drinks	 ...eason) once had one with Braggs and Thai basil at Cantina. The fact that my frie...
#  2 0.53 drinks	 ...Complete with your strawberry slices and basil, this thing is excessively easy t...
#  3 0.45 drinks	 ...$12) It had Absolut Vodka, Strawberries, Basil and Lemonade and my wife had a "H...
#  4 0.45 redsauce	 ...atering thinking about it right now....  Basil Gin-tini: Fresh muddled basil, fr...
#  5 0.39 drinks	 ...menu is also delightful! The grapefruit basil margarita calls my name regularly...
#  6 0.38 drinks	 ...r friendly items.  I had the mozzarella, basil, tomato salad (let's just call it...
#  7 0.38 drinks	 ...ab and not much filler. I had the tomato basil soup (soooo good!) and the candie...
#  8 0.37 drinks	 ...tains coconut milk and cream, as well as basil and a hint of chili, and is serve...
#  9 0.36 hotdish	 ...with unique drinks. I love the blueberry basil lemonade, lemon vodka, home made...
# 10 0.35 drinks	 ...nd the bacon infused vodka or the tomato basil infused. Mimosas blended just per...
# 11 0.34 redsauce	 ...small side salad of sliced asparagus and basil with tapenade. The only complaint...
# 12 0.34 hotdish	 ...bat-e rayhan (lemon rosewater drink with basil seeds), and it was also surprisin...
# 13 0.34 drinks	 ...n Giggle with Pop Rocks, Leblon cachaça, basil, coconut lemongrass nigori, lime...
# 14 0.33 drinks	 ...ktail. We started off with a mimosa with basil and a gin lemonade.- it was stron...
# 15 0.33 hotdish	 ...cided it tasted like coca-cola with some basil flavor.  Sounds weird? - well try...
# 16 0.33 redsauce	 ...t in, same thing with the calamari [just basil marinara rather than chili]. Spea...
# 17 0.32 drinks	 ...-made pasta with truffle, olive oil, and basil that I think about every day. So...
# 18 0.31 hotdish	 ...te rice wasn't enough. The chicken spicy basil fried rice was flavorful. The Tha...
# 19 0.31 hotdish	 ...elli (blistered cherry tomatoes, garlic, basil, burrata and tiny pasta) and my h...
# 20 0.31 drinks	 ...pecial drinks were great, we had the gin basil smash and the Doberman, I would r...
# ----------------------------------------------------------------------------------------
# BM25 query: basil cocktail
#  1 +0.38     drinks    an seared scallops in a strawberry basil sauce. We were so surprised when t
#  2 +0.37     drinks    away Vacation (Rum, lime, curacao, basil, chili, ginger, mint and coconut.)
#  3 +0.06    hotdish    omething different and ordered the basil fried rice. I highly recommend it!
#  4 +0.25    hotdish    my avocado, iceberg lettuce, mint, basil, cashews, and coconut tempura- a s
#  5 -0.14   redsauce    sweet sausage, marinated tomatoes, basil, organic mixed greens). You can't
#  6 +0.20    hotdish    a, prosciutto, mushrooms and fresh basil while my girlfriends father also o
#  7 +0.18    hotdish    d a little tangy with the taste of basil mellowing it out. The steak was te
#  8 +0.18    hotdish    /2 shell; scallops crab encrusted; basil drizzle.  But I recd 5 1/2 shells
#  9 +0.17   redsauce    rom too much salt)  as well as any basil as listed on the menu.  My husband
# 10 -0.15   redsauce    uld have settled for the marvelous basil aioli that came with the ingenious
# 11 +0.34   redsauce     was a bit bland - I think regular basil pesto would've been a better choic
# 12 +0.24     drinks    We had started with the garlic and basil deep fried wings and the steamed d
# 13 -0.13   redsauce     reviews raving about their tomato basil sauce I really wanted to try that
# 14 -0.11   colddish    y was a little bit off for me, the basil infused cream was a bit on the mil
# 15 +0.20   redsauce    d, and there was fresh, chiffonade basil ribbons throughout, which added ki
# 16 +0.15   redsauce     and eggplant in the sweet heavily basil based garlic sauce is a party for
# 17 +0.20     drinks    (no mentions of basil)
# 18 -0.11    hotdish    riced.   They should add a chicken basil rice option and make it cheaper -
# 19 +0.24    hotdish    di was great though--bolognese and basil. Their bolognese is incredible and
# 20 +0.14     drinks     my life.  For my entree I had the basil chicken with brown rice--it was fi
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('basil', 'basil curry', 'hotdish', ['curry', 'basil'], [1,-1])
# Out:
# Context vector query: basil + Vector([('curry', 1), ('basil', -1), ('basil', 1)] )
#  1 0.66 hotdish	 ...hai curry chicken, sushi rolls, and Thai basil curry. We really liked everything...
#  2 0.44 hotdish	 ...reen beans, broccoli, eggplant, and Thai basil. I took a few sips of the broth a...
#  3 0.41 hotdish	 ...ous. The spicy noodles had lots of fresh basil cooked into the spicy noodles and...
#  4 0.40 hotdish	 ...e dishes.  The stir fries -i.e. eggplant basil, basil leaves- are both awesome a...
#  5 0.36 hotdish	 ...made an especially flavorful curry with basil as the accent. I love that they g...
#  6 0.36 hotdish	 ...nner in a tropical garden. I ordered the Basil Eggplant, which was delicious, no...
#  7 0.34 redsauce	 ...ent. My daughter had mussels with tomato basil sauce, which was also very good....
#  8 0.33 hotdish	 ...y (Roasted Duck, Tomatoes, Bell Peppers, Basil Leaves and Pineapple in a Coconut...
#  9 0.33 hotdish	 ...th Lettuce, beansprout, onion, cilantro, basil, cucumber,carrot,spring roll, gri...
# 10 0.33 hotdish	 ...isits has proved to be very bad.  We got basil fried rice and the rice was sever...
# 11 0.33 hotdish	 ...got takeout from there 3 times, spicy basil shrimp, pad thai, chicken satay. it...
# 12 0.31 hotdish	 ...affordable prices. Chicken satay and the basil fried rice were great!  Parking w...
# 13 0.31 hotdish	 ...Delicious lunch! Hot is hot so beware. Basil dish w jalapeños spicy, but flavor...
# 14 0.30 hotdish	 ...ad:   - coconut soup - lemongrass soup - basil leaf stir-fry - ginger stir-fry -...
# 15 0.30 hotdish	 ...n, pineapple tofu curry, chopped chicken basil, etc... There are usually a few s...
# 16 0.30 hotdish	 ...like drunken noodles that have Bok choy, basil, egg and noodles like Siam and ni...
# 17 0.29 other	 ...ose rice, soup or salad. I got the spicy basil duck with rice and the beef pad s...
# 18 0.29 hotdish	 ...do like one of their soups, the one with basil and is a bit spicy. Other than th...
# 19 0.28 redsauce	 ...y, "small order" of mussels in the curry basil sauce, OMG--it was amazingly and...
# 20 0.28 hotdish	 ...the city, fried twice and served with a basil mayo.  THey do mussels and fries...
# ----------------------------------------------------------------------------------------
# BM25 query: basil curry
#  1 +0.33    hotdish    lso worth mentioning are the spicy basils stir fry, the spicy basil noodles
#  2 +0.36    hotdish    oodles in a spicy chili sauce with basil, napa, bean sprouts, and bell pepp
#  3 +0.28    hotdish    or the main course I got the spicy basil noodles with chicken also based on
#  4 +0.31    hotdish    (no mentions of basil)
#  5 +0.30    hotdish    (no mentions of basil)
#  6 +0.40    hotdish    es.  The stir fries -i.e. eggplant basil, basil leaves- are both awesome as
#  7 +0.41    hotdish    urry, pork green curry, and a tofu basil. All we're spiced well according t
#  8 +0.33    hotdish    e one that compares to the chicken basil at Green Mango!     Some of my fav
#  9 +0.26    hotdish    (no mentions of basil)
# 10 +0.33    hotdish    y in its own way. I got the strong basil flavor and the spice level was per
# 11 +0.36    hotdish    abocha squash, zucchini, carrots & basil; $12) with the "brown" rice. The c
# 12 +0.18    hotdish     and is tossed with bamboo shoots, basil, and maybe onion (I don't remember
# 13 +0.29    hotdish    omething different and ordered the basil fried rice. I highly recommend it!
# 14 +0.29      other    ting primal desires. Then the beef basil comes into play and I am taken to
# 15 +0.30    hotdish    - coconut soup - lemongrass soup - basil leaf stir-fry - ginger stir-fry -
# 16 +0.44    hotdish    the same party, we had the chicken basil, chicken red curry, pineapple frie
# 17 +0.21    hotdish    rs were there.   Plenty of bamboo, basil, and chicken.  I will definitely b
# 18 +0.28    hotdish    ts from the menu is in order: Thai basil, peas, green peppers, red peppers,
# 19 +0.28    hotdish    red curry, coconut milk, lime, and basil.  The heaping mound of mussels was
# 20 -0.32   colddish    - where you can actually taste the basil, iand several curries to dance on
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>

# %%
search('basil', 'thai basil curry', 'hotdish', ['curry', 'thai'], [1,1])
# Out:
# Context vector query: basil + Vector([('curry', 1), ('thai', 1), ('basil', 1)] )
#  1 0.67 hotdish	 ...hai curry chicken, sushi rolls, and Thai basil curry. We really liked everything...
#  2 0.58 hotdish	 ...te rice wasn't enough. The chicken spicy basil fried rice was flavorful. The Tha...
#  3 0.56 hotdish	 ...ous. The spicy noodles had lots of fresh basil cooked into the spicy noodles and...
#  4 0.54 hotdish	 ...reen beans, broccoli, eggplant, and Thai basil. I took a few sips of the broth a...
#  5 0.53 hotdish	 ...e dishes.  The stir fries -i.e. eggplant basil, basil leaves- are both awesome a...
#  6 0.52 hotdish	 ...nner in a tropical garden. I ordered the Basil Eggplant, which was delicious, no...
#  7 0.50 hotdish	 ...y (Roasted Duck, Tomatoes, Bell Peppers, Basil Leaves and Pineapple in a Coconut...
#  8 0.50 other	 ...ose rice, soup or salad. I got the spicy basil duck with rice and the beef pad s...
#  9 0.50 hotdish	 ...isits has proved to be very bad.  We got basil fried rice and the rice was sever...
# 10 0.50 hotdish	 ...made an especially flavorful curry with basil as the accent. I love that they g...
# 11 0.50 hotdish	 ...redients from the menu is in order: Thai basil, peas, green peppers, red peppers...
# 12 0.49 hotdish	 ...th Lettuce, beansprout, onion, cilantro, basil, cucumber,carrot,spring roll, gri...
# 13 0.49 hotdish	 ...Delicious lunch! Hot is hot so beware. Basil dish w jalapeños spicy, but flavor...
# 14 0.49 hotdish	 ...general top 10) on the planet. The Spicy Basil Noodles are to die for. When I'm...
# 15 0.49 hotdish	 ...d thai to the Kanok specialty, the spicy basil chicken.  As the name implies, it...
# 16 0.48 hotdish	 ...like drunken noodles that have Bok choy, basil, egg and noodles like Siam and ni...
# 17 0.48 hotdish	 ...got takeout from there 3 times, spicy basil shrimp, pad thai, chicken satay. it...
# 18 0.48 hotdish	 ...ad:   - coconut soup - lemongrass soup - basil leaf stir-fry - ginger stir-fry -...
# 19 0.46 hotdish	 ...a dry sandwich with cheese, chicken and basil. next time I'm going over to Prim...
# 20 0.46 hotdish	 ...auce, walnut shrimp, Mongolian beef, and basil chicken.  Hot and sour soup is be...
# ----------------------------------------------------------------------------------------
# BM25 query: thai basil curry
#  1 +0.50    hotdish    eir pad thai is good, as are their basil noodles. I really love their tom y
#  2 +0.49    hotdish    picy Thai fried rice but with Thai basil added (kind of like a cross betwee
#  3 +0.50    hotdish    an especially flavorful curry with basil as the accent. I love that they gi
#  4 +0.49    hotdish    (no mentions of basil)
#  5 +0.53    hotdish    es.  The stir fries -i.e. eggplant basil, basil leaves- are both awesome as
#  6 +0.48    hotdish    s sauce with the perfect amount of basil to cool your mouth off. And it's B
#  7 +0.56    hotdish    y. Soft nibblets of Asian pumpkin, basil, coconut milk, and a spicy red cur
#  8 +0.50    hotdish    e one that compares to the chicken basil at Green Mango!     Some of my fav
#  9 +0.48    hotdish    y in its own way. I got the strong basil flavor and the spice level was per
# 10 +0.52    hotdish    abocha squash, zucchini, carrots & basil; $12) with the "brown" rice. The c
# 11 +0.36    hotdish    (no mentions of basil)
# 12 +0.49    hotdish     them. Especially if you like Thai basil, because theirs are packed with th
# 13 +0.39    hotdish    (no mentions of basil)
# 14 +0.50      other    ting primal desires. Then the beef basil comes into play and I am taken to
# 15 +0.48    hotdish    el. Hot, but not unbearable.  Thai basil leaf chicken is what I like to cal
# 16 +0.54    hotdish    the same party, we had the chicken basil, chicken red curry, pineapple frie
# 17 +0.35    hotdish    (no mentions of basil)
# 18 -0.54   colddish    - where you can actually taste the basil, iand several curries to dance on
# 19 +0.50    hotdish    t of spiciness. I did try the Thai basil curry before, which was also good
# 20 -0.40    hotdish    rot, peas, pineapple, tomatoes and basil. The sweetness of the root vegetab
# ----------------------------------------------------------------------------------------
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~josephcc/124.embed" height="525px" width="100%"></iframe>
